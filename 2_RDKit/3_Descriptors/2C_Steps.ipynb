# %% [markdown]
# # Molecular properties in DataFrame

# %% [markdown]
# ## Define dictionary of molecules

# %%
molecules = {
    'Aspirin': 'CC(=O)OC1=CC=CC=C1C(=O)O',
    'Paracetamol': 'CC(=O)NC1=CC=C(O)C=C1',
    'Caffeine': 'CN1C=NC2=C1C(=O)N(C(=O)N2C)C',
    'Ibuprofen': 'CC(C)CC1=CC=C(C=C1)C(C)C(=O)O',
    'Penicillin G': 'CC1(C(=O)NC(=O)C2=CSC(N3CCOC3)=N12)C(O)=O',
    'Atorvastatin': 'CC(C)C1=CC=C(C=C1)C2=C(C(=O)N(C(=O)N2C)C(C3=CC=CC=C3)O)O',
    'Metformin': 'CNC(=N)NC(=N)N(C)C',
    'Simvastatin': 'CCC(C)C(C(=O)OC1CCC2(C1C3CC(O3)C(=O)O2)C)OC',
    'Losartan': 'CC(C)CC1=CC=C(C=C1)C2=CNC3=CC=CC=C3N2C(=O)O',
    'Amoxicillin': 'CC1(C(=O)NC(=O)C2=CSC(N3CCOC3)=N12)C(O)=O'
}

# %% [markdown]
# ## Calculate molecular properties

# %%
from src.utils import MolecularPropertiesCalculator

calculator = MolecularPropertiesCalculator(molecules)
df = calculator.calculate(as_df=True)
df
# Out:
# [15:25:22] Explicit valence for atom # 16 N, 4, is greater than permitted
# [15:25:22] Explicit valence for atom # 16 N, 4, is greater than permitted
#                   MW    LogP  HBD  HBA   RB   AR   TPSA   HAC      FSP3  \
# Aspirin      180.159  1.3101  1.0  3.0  2.0  1.0  63.60  13.0  0.111111
# Paracetamol  151.165  1.3506  2.0  2.0  1.0  1.0  49.33  11.0  0.125000
# ...              ...     ...  ...  ...  ...  ...    ...   ...       ...
# Simvastatin  326.389  1.8423  0.0  6.0  5.0  0.0  71.06  23.0  0.882353
# Losartan     308.381  4.7936  2.0  2.0  3.0  2.0  52.57  23.0  0.210526
#
#                     ASA                                       smiles
# Aspirin       74.757053                     CC(=O)OC1=CC=CC=C1C(=O)O
# Paracetamol   64.666905                        CC(=O)NC1=CC=C(O)C=C1
# ...                 ...                                          ...
# Simvastatin  136.338057  CCC(C)C(C(=O)OC1CCC2(C1C3CC(O3)C(=O)O2)C)OC
# Losartan     135.613110  CC(C)CC1=CC=C(C=C1)C2=CNC3=CC=CC=C3N2C(=O)O
#
# [8 rows x 11 columns]

# %% [markdown]
# ## Ranking

# %% [markdown]
# ### Drop SMILES column

# %%
df = df.drop(columns=['smiles'])
df
# Out:
#                   MW    LogP  HBD  HBA   RB   AR   TPSA   HAC      FSP3  \
# Aspirin      180.159  1.3101  1.0  3.0  2.0  1.0  63.60  13.0  0.111111
# Paracetamol  151.165  1.3506  2.0  2.0  1.0  1.0  49.33  11.0  0.125000
# ...              ...     ...  ...  ...  ...  ...    ...   ...       ...
# Simvastatin  326.389  1.8423  0.0  6.0  5.0  0.0  71.06  23.0  0.882353
# Losartan     308.381  4.7936  2.0  2.0  3.0  2.0  52.57  23.0  0.210526
#
#                     ASA
# Aspirin       74.757053
# Paracetamol   64.666905
# ...                 ...
# Simvastatin  136.338057
# Losartan     135.613110
#
# [8 rows x 10 columns]

# %% [markdown]
# ### Sort values

# %%
df = df.sort_values(by='MW', ascending=False)
df
# Out:
#                    MW     LogP  HBD  HBA   RB   AR   TPSA   HAC      FSP3  \
# Atorvastatin  366.417  2.58220  2.0  6.0  4.0  3.0  84.46  27.0  0.238095
# Simvastatin   326.389  1.84230  0.0  6.0  5.0  0.0  71.06  23.0  0.882353
# ...               ...      ...  ...  ...  ...  ...    ...   ...       ...
# Paracetamol   151.165  1.35060  2.0  2.0  1.0  1.0  49.33  11.0  0.125000
# Metformin     143.194 -0.77346  4.0  2.0  0.0  0.0  75.00  10.0  0.600000
#
#                      ASA
# Atorvastatin  156.141053
# Simvastatin   136.338057
# ...                  ...
# Paracetamol    64.666905
# Metformin      60.429280
#
# [8 rows x 10 columns]

# %% [markdown]
# ### Styles

# %%
dfs = (df
 .style
    .background_gradient(cmap='Purples', axis=0)
    .format(precision=1)
)

dfs
# Out:
# <style type="text/css">
# #T_94c62_row0_col0, #T_94c62_row0_col3, #T_94c62_row0_col5, #T_94c62_row0_col6, #T_94c62_row0_col7, #T_94c62_row0_col9, #T_94c62_row1_col3, #T_94c62_row1_col4, #T_94c62_row1_col8, #T_94c62_row2_col1, #T_94c62_row4_col3, #T_94c62_row7_col2 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_94c62_row0_col1 {
#   background-color: #817ebb;
#   color: #f1f1f1;
# }
# #T_94c62_row0_col2, #T_94c62_row2_col2, #T_94c62_row6_col2 {
#   background-color: #9e9ac8;
#   color: #f1f1f1;
# }
# #T_94c62_row0_col4, #T_94c62_row3_col4, #T_94c62_row7_col6 {
#   background-color: #61409b;
#   color: #f1f1f1;
# }
# #T_94c62_row0_col8, #T_94c62_row5_col0 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_94c62_row1_col0 {
#   background-color: #5d3897;
#   color: #f1f1f1;
# }
# #T_94c62_row1_col1 {
#   background-color: #9f9cc9;
#   color: #f1f1f1;
# }
# #T_94c62_row1_col2, #T_94c62_row1_col5, #T_94c62_row3_col3, #T_94c62_row3_col6, #T_94c62_row4_col1, #T_94c62_row4_col2, #T_94c62_row4_col4, #T_94c62_row5_col8, #T_94c62_row7_col0, #T_94c62_row7_col4, #T_94c62_row7_col5, #T_94c62_row7_col7, #T_94c62_row7_col9 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_94c62_row1_col6 {
#   background-color: #705ca9;
#   color: #f1f1f1;
# }
# #T_94c62_row1_col7, #T_94c62_row2_col7 {
#   background-color: #674ca1;
#   color: #f1f1f1;
# }
# #T_94c62_row1_col9 {
#   background-color: #62429c;
#   color: #f1f1f1;
# }
# #T_94c62_row2_col0 {
#   background-color: #6c54a5;
#   color: #f1f1f1;
# }
# #T_94c62_row2_col3, #T_94c62_row6_col3, #T_94c62_row6_col4, #T_94c62_row7_col3 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# #T_94c62_row2_col4 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_94c62_row2_col5, #T_94c62_row4_col5 {
#   background-color: #796eb2;
#   color: #f1f1f1;
# }
# #T_94c62_row2_col6 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_94c62_row2_col8 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_94c62_row2_col9 {
#   background-color: #63449d;
#   color: #f1f1f1;
# }
# #T_94c62_row3_col0 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_94c62_row3_col1 {
#   background-color: #7261ab;
#   color: #f1f1f1;
# }
# #T_94c62_row3_col2, #T_94c62_row5_col2 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_94c62_row3_col5, #T_94c62_row5_col5, #T_94c62_row6_col5 {
#   background-color: #c6c7e1;
#   color: #000000;
# }
# #T_94c62_row3_col7 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_94c62_row3_col8 {
#   background-color: #a9a7cf;
#   color: #f1f1f1;
# }
# #T_94c62_row3_col9 {
#   background-color: #cacae3;
#   color: #000000;
# }
# #T_94c62_row4_col0 {
#   background-color: #dedded;
#   color: #000000;
# }
# #T_94c62_row4_col6 {
#   background-color: #9995c6;
#   color: #f1f1f1;
# }
# #T_94c62_row4_col7 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_94c62_row4_col8 {
#   background-color: #c4c5e0;
#   color: #000000;
# }
# #T_94c62_row4_col9 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_94c62_row5_col1, #T_94c62_row5_col3, #T_94c62_row5_col4 {
#   background-color: #b6b6d8;
#   color: #000000;
# }
# #T_94c62_row5_col6 {
#   background-color: #908dc2;
#   color: #f1f1f1;
# }
# #T_94c62_row5_col7 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_94c62_row5_col9 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_94c62_row6_col0 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_94c62_row6_col1 {
#   background-color: #b4b4d7;
#   color: #000000;
# }
# #T_94c62_row6_col6 {
#   background-color: #d9d9ea;
#   color: #000000;
# }
# #T_94c62_row6_col7 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_94c62_row6_col8 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_94c62_row6_col9, #T_94c62_row7_col1 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_94c62_row7_col8 {
#   background-color: #7e79b8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_94c62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94c62_level0_col0" class="col_heading level0 col0" >MW</th>
#       <th id="T_94c62_level0_col1" class="col_heading level0 col1" >LogP</th>
#       <th id="T_94c62_level0_col2" class="col_heading level0 col2" >HBD</th>
#       <th id="T_94c62_level0_col3" class="col_heading level0 col3" >HBA</th>
#       <th id="T_94c62_level0_col4" class="col_heading level0 col4" >RB</th>
#       <th id="T_94c62_level0_col5" class="col_heading level0 col5" >AR</th>
#       <th id="T_94c62_level0_col6" class="col_heading level0 col6" >TPSA</th>
#       <th id="T_94c62_level0_col7" class="col_heading level0 col7" >HAC</th>
#       <th id="T_94c62_level0_col8" class="col_heading level0 col8" >FSP3</th>
#       <th id="T_94c62_level0_col9" class="col_heading level0 col9" >ASA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94c62_level0_row0" class="row_heading level0 row0" >Atorvastatin</th>
#       <td id="T_94c62_row0_col0" class="data row0 col0" >366.4</td>
#       <td id="T_94c62_row0_col1" class="data row0 col1" >2.6</td>
#       <td id="T_94c62_row0_col2" class="data row0 col2" >2.0</td>
#       <td id="T_94c62_row0_col3" class="data row0 col3" >6.0</td>
#       <td id="T_94c62_row0_col4" class="data row0 col4" >4.0</td>
#       <td id="T_94c62_row0_col5" class="data row0 col5" >3.0</td>
#       <td id="T_94c62_row0_col6" class="data row0 col6" >84.5</td>
#       <td id="T_94c62_row0_col7" class="data row0 col7" >27.0</td>
#       <td id="T_94c62_row0_col8" class="data row0 col8" >0.2</td>
#       <td id="T_94c62_row0_col9" class="data row0 col9" >156.1</td>
#     </tr>
#     <tr>
#       <th id="T_94c62_level0_row1" class="row_heading level0 row1" >Simvastatin</th>
#       <td id="T_94c62_row1_col0" class="data row1 col0" >326.4</td>
#       <td id="T_94c62_row1_col1" class="data row1 col1" >1.8</td>
#       <td id="T_94c62_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_94c62_row1_col3" class="data row1 col3" >6.0</td>
#       <td id="T_94c62_row1_col4" class="data row1 col4" >5.0</td>
#       <td id="T_94c62_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_94c62_row1_col6" class="data row1 col6" >71.1</td>
#       <td id="T_94c62_row1_col7" class="data row1 col7" >23.0</td>
#       <td id="T_94c62_row1_col8" class="data row1 col8" >0.9</td>
#       <td id="T_94c62_row1_col9" class="data row1 col9" >136.3</td>
#     </tr>
#     <tr>
#       <th id="T_94c62_level0_row2" class="row_heading level0 row2" >Losartan</th>
#       <td id="T_94c62_row2_col0" class="data row2 col0" >308.4</td>
#       <td id="T_94c62_row2_col1" class="data row2 col1" >4.8</td>
#       <td id="T_94c62_row2_col2" class="data row2 col2" >2.0</td>
#       <td id="T_94c62_row2_col3" class="data row2 col3" >2.0</td>
#       <td id="T_94c62_row2_col4" class="data row2 col4" >3.0</td>
#       <td id="T_94c62_row2_col5" class="data row2 col5" >2.0</td>
#       <td id="T_94c62_row2_col6" class="data row2 col6" >52.6</td>
#       <td id="T_94c62_row2_col7" class="data row2 col7" >23.0</td>
#       <td id="T_94c62_row2_col8" class="data row2 col8" >0.2</td>
#       <td id="T_94c62_row2_col9" class="data row2 col9" >135.6</td>
#     </tr>
#     <tr>
#       <th id="T_94c62_level0_row3" class="row_heading level0 row3" >Ibuprofen</th>
#       <td id="T_94c62_row3_col0" class="data row3 col0" >206.3</td>
#       <td id="T_94c62_row3_col1" class="data row3 col1" >3.1</td>
#       <td id="T_94c62_row3_col2" class="data row3 col2" >1.0</td>
#       <td id="T_94c62_row3_col3" class="data row3 col3" >1.0</td>
#       <td id="T_94c62_row3_col4" class="data row3 col4" >4.0</td>
#       <td id="T_94c62_row3_col5" class="data row3 col5" >1.0</td>
#       <td id="T_94c62_row3_col6" class="data row3 col6" >37.3</td>
#       <td id="T_94c62_row3_col7" class="data row3 col7" >15.0</td>
#       <td id="T_94c62_row3_col8" class="data row3 col8" >0.5</td>
#       <td id="T_94c62_row3_col9" class="data row3 col9" >90.9</td>
#     </tr>
#     <tr>
#       <th id="T_94c62_level0_row4" class="row_heading level0 row4" >Caffeine</th>
#       <td id="T_94c62_row4_col0" class="data row4 col0" >194.2</td>
#       <td id="T_94c62_row4_col1" class="data row4 col1" >-1.0</td>
#       <td id="T_94c62_row4_col2" class="data row4 col2" >0.0</td>
#       <td id="T_94c62_row4_col3" class="data row4 col3" >6.0</td>

# %% [markdown]
# ### Output

# %%
import dataframe_image as dfi

dfi.export(dfs, 'molecular_properties.png')
